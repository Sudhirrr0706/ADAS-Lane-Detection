# %%
import cv2
import os
import glob
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img_dir = "C:\\Users\\Tallam Tharun Sai\\test_images"
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data = []
for f1 in files:
    img = cv2.imread(f1)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    data.append(img)

# %%
def display_images(images, cmap=None):
    plt.figure(figsize=(40,40))
    for i, image in enumerate(images):
        plt.subplot(3,2,i+1)
        plt.imshow(image, cmap)
        plt.autoscale(tight=True)
    plt.show()

# %%
display_images(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-a7d3138a485e> in <module>()
# ----> 1 display_images(data)
#
# <ipython-input-45-648337e92de8> in display_images(images, cmap)
#       2     plt.figure(figsize=(40,40))
#       3     for i, image in enumerate(images):
# ----> 4         plt.subplot(3,2,i+1)
#       5         plt.imshow(image, cmap)
#       6         plt.autoscale(tight=True)
#
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# F:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      65                     raise ValueError(
#      66                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 67                         ).format(maxn=rows*cols, num=num))
#      68                 self._subplotspec = GridSpec(
#      69                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 6, not 7

# %%
import numpy as np

# %%
def color_filter(image):
    #convert to HLS to mask based on HLS
    hls = cv2.cvtColor(image, cv2.COLOR_RGB2HLS)
    lower = np.array([0,190,0])
    upper = np.array([255,255,255])
    yellower = np.array([10,0,90])
    yelupper = np.array([50,255,255])
    yellowmask = cv2.inRange(hls, yellower, yelupper)
    whitemask = cv2.inRange(hls, lower, upper)
    mask = cv2.bitwise_or(yellowmask, whitemask)  #bitwise_or
    masked = cv2.bitwise_and(image, image, mask = mask) #bitwise_and
    return masked

# %%
filtered_img = list(map(color_filter, data))

# %%
display_images(filtered_img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-40c34ccb08ab> in <module>()
# ----> 1 display_images(filtered_img)
#
# <ipython-input-45-648337e92de8> in display_images(images, cmap)
#       2     plt.figure(figsize=(40,40))
#       3     for i, image in enumerate(images):
# ----> 4         plt.subplot(3,2,i+1)
#       5         plt.imshow(image, cmap)
#       6         plt.autoscale(tight=True)
#
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# F:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      65                     raise ValueError(
#      66                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 67                         ).format(maxn=rows*cols, num=num))
#      68                 self._subplotspec = GridSpec(
#      69                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 6, not 7

# %%
def roi(img):
    x = int(img.shape[1])
    y = int(img.shape[0])
    shape = np.array([[int(0), int(y)], [int(x), int(y)], [int(0.55*x), int(0.6*y)], [int(0.45*x), int(0.6*y)]])
    #define a numpy array with the dimensions of img, but comprised of zeros
    mask = np.zeros_like(img)
    #Uses 3 channels or 1 channel for 6color depending on input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
    #creates a polygon with the mask color
    cv2.fillPoly(mask, np.int32([shape]), ignore_mask_color)
    #returns the image only where the mask pixels are not zero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

# %%
roi_img = list(map(roi, filtered_img))

# %%
display_images(roi_img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-4e0aedec7edf> in <module>()
# ----> 1 display_images(roi_img)
#
# <ipython-input-45-648337e92de8> in display_images(images, cmap)
#       2     plt.figure(figsize=(40,40))
#       3     for i, image in enumerate(images):
# ----> 4         plt.subplot(3,2,i+1)
#       5         plt.imshow(image, cmap)
#       6         plt.autoscale(tight=True)
#
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# F:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      65                     raise ValueError(
#      66                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 67                         ).format(maxn=rows*cols, num=num))
#      68                 self._subplotspec = GridSpec(
#      69                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 6, not 7

# %%
def grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
def canny(img):
    return cv2.Canny(grayscale(img), 50, 120)
canny_img = list(map(canny, roi_img))
display_images(canny_img,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-0f1acc56d25b> in <module>()
#       4     return cv2.Canny(grayscale(img), 50, 120)
#       5 canny_img = list(map(canny, roi_img))
# ----> 6 display_images(canny_img,cmap='gray')
#
# <ipython-input-19-648337e92de8> in display_images(images, cmap)
#       2     plt.figure(figsize=(40,40))
#       3     for i, image in enumerate(images):
# ----> 4         plt.subplot(3,2,i+1)
#       5         plt.imshow(image, cmap)
#       6         plt.autoscale(tight=True)
#
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# F:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      65                     raise ValueError(
#      66                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 67                         ).format(maxn=rows*cols, num=num))
#      68                 self._subplotspec = GridSpec(
#      69                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 6, not 7
